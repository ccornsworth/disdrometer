# %% [markdown]
# # RAMP AQ Data

# %% [markdown]
# RAMP AQ data from the WFRT rooftop is read in with the function below.

# %%
from func import run

run()
# Out:
# Today is 2026-06-22.
#   0% [                                                                            ]      0 / 502942
#  19% [..............                                                              ]  98304 / 502942
#  83% [...............................................................             ] 417792 / 502942
# 100% [............................................................................] 502942 / 502942
#  13% [..........                                                                  ]  65536 / 495645
#  51% [......................................                                      ] 253952 / 495645
# 100% [............................................................................] 495645 / 495645
#  11% [........                                                                    ]  57344 / 494172
#  62% [...............................................                             ] 311296 / 494172
# ...
